# %%
import magenta #pip install magenta
import tensorflow as tf #conda install keras
import matplotlib.pyplot as plt #pip install matplotlib
import numpy as np 
import magenta.music as mm # plotting only works in notebook switch lab to tree in url. 
import ctypes.util
from fluidsynth_204 import *
from magenta.protobuf import music_pb2


import ctypes.util
orig_ctypes_util_find_library = ctypes.util.find_library
def proxy_find_library(lib):
  if lib == 'fluidsynth':
    return 'libfluidsynth.so.1'
  else:
    return orig_ctypes_util_find_library(lib)
ctypes.util.find_library = proxy_find_library

# %%
from bokeh.io import export_png

# %%
from ctypes import *
from ctypes.util import find_library
from future.utils import iteritems

# %%
lib = find_library('fluidsynth') or \
    find_library('libfluidsynth') or \
    find_library('libfluidsynth-1')

# %%
print(f"Magenta ver: {magenta.__version__}")
print(f"tensorflow ver: {tf.__version__}")
print(lib)
# Out:
# Magenta ver: 1.0.2
# tensorflow ver: 1.12.0
# libfluidsynth.so.1

# %%
df1 = cs1 = 1
df2 = cs2 = cs1+12
df3 = cs3 = cs2+12
df4 = cs4 = cs3+12
df5 = cs5 = cs4+12
df6 = cs6 = cs5+12
df7 = cs7 = cs6+12
df8 = cs8 = cs7+12
df9 = cs9 = cs8+12
df10 = cs10 = cs9+12
df11 = cs11 = cs10+12
c2 = 12
c3 = c2+12
c4 = c3+12
c5 = c4+12
c6 = c5+12
c7 = c6+12
c8 = c7+12
c9 = c8+12
c10 = c9+12
c11 = c10+12

d1 = 2
d2 = d1+12
d3 = d2+12
d4 = d3+12
d5 = d4+12
d6 = d5+12
d7 = d6+12
d8 = d7+12
d9 = d8+12
d10 = d9+12
d11 = d10+12
ef1 = ds1 = 3
ef2 = ds2 = ds1+12
ef3 = ds3 = ds2+12
ef4 = ds4 = ds3+12
ef5 = ds5 = ds4+12
ef6 = ds6 = ds5+12
ef7 = ds7 = ds6+12
ef8 = ds8 = ds7+12
ef9 = ds9 = ds8+12
ef10 = ds10 = ds9+12
ef11 = ds11 = ds10+12

e1 = 4
e2 = e1+12
e3 = e2+12
e4 = e3+12
e5 = e4+12
e6 = e5+12
e7 = e6+12
e8 = e7+12
e9 = e8+12
e10 = e9+12
e11 = e10+12

f1 = 5
f2 = f1+12
f3 = f2+12
f4 = f3+12
f5 = f4+12
f6 = f5+12
f7 = f6+12
f8 = f7+12
f9 = f8+12
f10 = f9+12
f11 = f10+12
gf1 = fs1 = 6
gf2 = fs2 = fs1+12
gf3 = fs3 = fs2+12
gf4 = fs4 = fs3+12
gf5 = fs5 = fs4+12
gf6 = fs6 = fs5+12
gf7 = fs7 = fs6+12
gf8 = fs8 = fs7+12
gf9 = fs9 = fs8+12
gf10 = fs10 = fs9+12
gf11 = fs11 = fs10+12

g1 = 7
g2 = g1+12
g3 = g2+12
g4 = g3+12
g5 = g4+12
g6 = g5+12
g7 = g6+12
g8 = g7+12
g9 = g8+12
g10 = g9+12
g11 = g10+12

af1 = gs1 = 8
af2 = gs2 = gs1+12
af3 = gs3 = gs2+12
af4 = gs4 = gs3+12
af5 = gs5 = gs4+12
af6 = gs6 = gs5+12
af7 = gs7 = gs6+12
af8 = gs8 = gs7+12
af9 = gs9 = gs8+12
af10 = gs10 = gs9+12

a1 = 9
a2 = a1+12
a3 = a2+12
a4 = a3+12
a5 = a4+12
a6 = a5+12
a7 = a6+12
a8 = a7+12
a9 = a8+12
a10 = a9+12
bf1 = as1 = 10
bf2 = as2 = as1+12
bf3 = as3 = as2+12
bf4 = as4 = as3+12
bf5 = as5 = as4+12
bf6 = as6 = as5+12
bf7 = as7 = as6+12
bf8 = as8 = as7+12
bf9 = as9 = as8+12
bf10 = as10 = as9+12

b1 = 11
b2 = b1+12
b3 = b2+12
b4 = b3+12
b5 = b4+12
b6 = b5+12
b7 = b6+12
b8 = b7+12
b9 = b8+12
b10 = b9+12

# %%
g11
# Out:
# 127

# %%
ns_path = "midi_conversion\output_zelda\zelda_collec"
# Out:
# <input>:1: DeprecationWarning: invalid escape sequence \o
# <input>:1: DeprecationWarning: invalid escape sequence \o
# <input>:1: DeprecationWarning: invalid escape sequence \o
# <ipython-input-12-71b7728d6e5d>:1: DeprecationWarning: invalid escape sequence \o
#   ns_path = "midi_conversion\output_zelda\zelda_collec"

# %%
saints_test = music_pb2.NoteSequence()
saints_test.notes.add(pitch=c6, start_time=0.0, end_time = 0.5, velocity = 80)
saints_test.notes.add(pitch=e6, start_time=0.5, end_time = 1.0, velocity = 80)
saints_test.notes.add(pitch=f6, start_time=1.0, end_time = 1.5, velocity = 80)
saints_test.notes.add(pitch=g6, start_time=1.5, end_time = 2.5, velocity = 80)
saints_test.notes.add(pitch=c6, start_time=2.5, end_time = 3.0, velocity = 80)
saints_test.notes.add(pitch=e6, start_time=3.0, end_time = 3.5, velocity = 80)
saints_test.notes.add(pitch=f6, start_time=3.5, end_time = 4.0, velocity = 80)
saints_test.notes.add(pitch=g6, start_time=4.0, end_time = 5.0, velocity = 80)
saints_test.notes.add(pitch=c6, start_time=5.0, end_time = 5.5, velocity = 80)
saints_test.notes.add(pitch=e6, start_time=5.5, end_time = 6.0, velocity = 80)
saints_test.notes.add(pitch=f6, start_time=6.0, end_time = 6.5, velocity = 80)
saints_test.notes.add(pitch=g6, start_time=6.5, end_time = 7.5, velocity = 80)
saints_test.notes.add(pitch=e6, start_time=7.5, end_time = 8.5, velocity = 80)
saints_test.notes.add(pitch=c6, start_time=8.5, end_time = 9.5, velocity = 80)
saints_test.notes.add(pitch=e6, start_time=9.5, end_time = 10.5, velocity = 80)
saints_test.notes.add(pitch=d6, start_time=10.5, end_time = 11.5, velocity = 80)
mm.plot_sequence(saints_test)
mm.sequence_proto_to_midi_file(saints_test, 'saints.mid')
saints_test.tempos.add(qpm=120)
saints_plot = mm.plot_sequence(saints_test)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b3b6a3e2-f668-40b1-b97e-cfd739416679">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c489eb30-438d-40db-94c3-d60a68ba7696"></div>
# </div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="032c56f8-361f-4477-b231-7d550df3f2ab">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="d23280fb-052c-41a8-b80c-99b4feca3bc7"></div>
# </div>

# %%
saints_test = music_pb2.NoteSequence()
saints_test.notes.add(pitch=c6, start_time=0.0, end_time = 0.5, velocity = 80)
saints_test.notes.add(pitch=e6, start_time=0.5, end_time = 1.0, velocity = 80)
saints_test.notes.add(pitch=f6, start_time=1.0, end_time = 1.5, velocity = 80)
saints_test.notes.add(pitch=g6, start_time=1.5, end_time = 2.5, velocity = 80)
saints_test.notes.add(pitch=c6, start_time=2.5, end_time = 3.0, velocity = 80)
saints_test.notes.add(pitch=e6, start_time=3.0, end_time = 3.5, velocity = 80)
saints_test.notes.add(pitch=f6, start_time=3.5, end_time = 4.0, velocity = 80)
saints_test.notes.add(pitch=g6, start_time=4.0, end_time = 5.0, velocity = 80)
saints_test.notes.add(pitch=c6, start_time=5.0, end_time = 5.5, velocity = 80)
saints_test.notes.add(pitch=e6, start_time=5.5, end_time = 6.0, velocity = 80)
saints_test.notes.add(pitch=f6, start_time=6.0, end_time = 6.5, velocity = 80)
saints_test.notes.add(pitch=g6, start_time=6.5, end_time = 7.5, velocity = 80)
saints_test.notes.add(pitch=e6, start_time=7.5, end_time = 8.5, velocity = 80)
saints_test.notes.add(pitch=c6, start_time=8.5, end_time = 9.5, velocity = 80)
saints_test.notes.add(pitch=e6, start_time=9.5, end_time = 10.5, velocity = 80)
saints_test.notes.add(pitch=d6, start_time=10.5, end_time = 11.5, velocity = 80)
mm.plot_sequence(saints_test)
mm.sequence_proto_to_midi_file(saints_test, 'saints.mid')
saints_test.tempos.add(qpm=120)
saints_plot = mm.plot_sequence(saints_test)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1bff6448-9406-4e96-b197-7014f9570471">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e326df72-f5cd-415c-90b7-3cfaa5ffc360"></div>
# </div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0be56a5c-304d-4eca-89e2-2c0678e23c91">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c26b88bd-07e0-492d-96db-9eafe99eef47"></div>
# </div>

# %%
#export_png(mm.plot_sequence(saints_test), filename="saints.png")

# %%
type(saints_test)
# Out:
# music_pb2.NoteSequence

# %%
for note in saints_test[notes]:
    print(note)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-582e1143a56b> in <module>()
# ----> 1 for note in saints_test[notes]:
#       2     print(note)
#
# NameError: name 'notes' is not defined

# %%
#spacer

# %%
mary_test = music_pb2.NoteSequence()
mary_test.notes.add(pitch=60, start_time=0.0, end_time=0.5, velocity=80)
mary_test.notes.add(pitch=60, start_time=0.5, end_time=1.0, velocity=80)
mary_test.notes.add(pitch=60, start_time=1.0, end_time=1.5, velocity=80)
mary_test.notes.add(pitch=60, start_time=1.5, end_time=2.0, velocity=80)
mary_test.notes.add(pitch=60, start_time=2.0, end_time=2.5, velocity=80)
mary_test.notes.add(pitch=60, start_time=2.5, end_time=3.0, velocity=80)
mary_test.notes.add(pitch=60, start_time=3.0, end_time=3.5, velocity=80)
mary_test.notes.add(pitch=60, start_time=3.4, end_time=4.0, velocity=80)
mm.plot_sequence(mary_test)
mm.sequence_proto_to_midi_file(mary_test, 'mary_had_a_little_lamb.mid')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="bc46a79d-1ad9-4665-8d3b-b5ea5eccbbad">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e052cff8-c1e3-404c-a36f-2a135b2924d7"></div>
# </div>

# %%
twinkle_twinkle = music_pb2.NoteSequence()

# Add the notes to the sequence.
twinkle_twinkle.notes.add(pitch=60, start_time=0.0, end_time=0.5, velocity=80)
twinkle_twinkle.notes.add(pitch=60, start_time=0.5, end_time=1.0, velocity=80)
twinkle_twinkle.notes.add(pitch=67, start_time=1.0, end_time=1.5, velocity=80)
twinkle_twinkle.notes.add(pitch=67, start_time=1.5, end_time=2.0, velocity=80)
twinkle_twinkle.notes.add(pitch=69, start_time=2.0, end_time=2.5, velocity=80)
twinkle_twinkle.notes.add(pitch=69, start_time=2.5, end_time=3.0, velocity=80)
twinkle_twinkle.notes.add(pitch=67, start_time=3.0, end_time=4.0, velocity=80)
twinkle_twinkle.notes.add(pitch=65, start_time=4.0, end_time=4.5, velocity=80)
twinkle_twinkle.notes.add(pitch=65, start_time=4.5, end_time=5.0, velocity=80)
twinkle_twinkle.notes.add(pitch=64, start_time=5.0, end_time=5.5, velocity=80)
twinkle_twinkle.notes.add(pitch=64, start_time=5.5, end_time=6.0, velocity=80)
twinkle_twinkle.notes.add(pitch=62, start_time=6.0, end_time=6.5, velocity=80)
twinkle_twinkle.notes.add(pitch=62, start_time=6.5, end_time=7.0, velocity=80)
twinkle_twinkle.notes.add(pitch=60, start_time=7.0, end_time=8.0, velocity=80)
# add harmony 
twinkle_twinkle.notes.add(pitch=55, start_time=0.0, end_time=0.5, velocity=80)
twinkle_twinkle.notes.add(pitch=55, start_time=0.5, end_time=1.0, velocity=80)
twinkle_twinkle.notes.add(pitch=63, start_time=1.0, end_time=1.5, velocity=80)
twinkle_twinkle.notes.add(pitch=63, start_time=1.5, end_time=2.0, velocity=80)
twinkle_twinkle.notes.add(pitch=64, start_time=2.0, end_time=2.5, velocity=80)
twinkle_twinkle.notes.add(pitch=64, start_time=2.5, end_time=3.0, velocity=80)
twinkle_twinkle.notes.add(pitch=62, start_time=3.0, end_time=4.0, velocity=80)
twinkle_twinkle.notes.add(pitch=60, start_time=4.0, end_time=4.5, velocity=80)
twinkle_twinkle.notes.add(pitch=60, start_time=4.5, end_time=5.0, velocity=80)
twinkle_twinkle.notes.add(pitch=59, start_time=5.0, end_time=5.5, velocity=80)
twinkle_twinkle.notes.add(pitch=59, start_time=5.5, end_time=6.0, velocity=80)
twinkle_twinkle.notes.add(pitch=57, start_time=6.0, end_time=6.5, velocity=80)
twinkle_twinkle.notes.add(pitch=57, start_time=6.5, end_time=7.0, velocity=80)
twinkle_twinkle.notes.add(pitch=55, start_time=7.0, end_time=8.0, velocity=80) 
twinkle_twinkle.total_time = 8

twinkle_twinkle.tempos.add(qpm=60);

# %%
mm.plot_sequence(twinkle_twinkle)
mm.sequence_proto_to_midi_file(twinkle_twinkle, 'twinkle_twinkle.mid')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ec3ddae2-6871-45c5-aa91-7b0328d7d642">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="799d303e-3ba2-4ae9-a402-3947fe909c76"></div>
# </div>

# %%
drums = music_pb2.NoteSequence()

drums.notes.add(pitch=36, start_time=0, end_time=0.125, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=38, start_time=0, end_time=0.125, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=42, start_time=0, end_time=0.125, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=46, start_time=0, end_time=0.125, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=42, start_time=0.25, end_time=0.375, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=42, start_time=0.375, end_time=0.5, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=42, start_time=0.5, end_time=0.625, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=50, start_time=0.5, end_time=0.625, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=36, start_time=0.75, end_time=0.875, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=38, start_time=0.75, end_time=0.875, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=42, start_time=0.75, end_time=0.875, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=45, start_time=0.75, end_time=0.875, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=36, start_time=1, end_time=1.125, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=42, start_time=1, end_time=1.125, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=46, start_time=1, end_time=1.125, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=42, start_time=1.25, end_time=1.375, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=48, start_time=1.25, end_time=1.375, is_drum=True, instrument=10, velocity=80)
drums.notes.add(pitch=50, start_time=1.25, end_time=1.375, is_drum=True, instrument=10, velocity=80)
drums.total_time = 1.375

drums.tempos.add(qpm=60)

# This is a colab utility method that visualizes a NoteSequence.
mm.plot_sequence(drums)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6b715956-43e0-4c64-85a6-c4c1b4356cd3">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="0b068c53-7ca7-4d08-9aa1-445362a6ff0c"></div>
# </div>

# %%
#twinkle_twinkle

# %%
# This creates a file called `drums_sample_output.mid`, containing the drums solo we've been using.
mm.sequence_proto_to_midi_file(drums, 'drums_sample_output.mid')

#with open("drums_sample_output.mid",'w',encoding = 'utf-8') as f:
#   f.write("drums_sample_output.mid")

# %%
mm.notebook_utils.download_bundle('basic_rnn.mag', '/content/')
bundle = mm.sequence_generator_bundle.read_bundle_file('/content/basic_rnn.mag')

# %%
from magenta.models.melody_rnn import melody_rnn_sequence_generator
from magenta.protobuf import generator_pb2
from magenta.protobuf import music_pb2

# %%
generator_map = melody_rnn_sequence_generator.get_generator_map()
melody_rnn = generator_map['basic_rnn'](checkpoint=None, bundle=bundle)
melody_rnn.initialize()
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from C:\Users\misir\AppData\Local\Temp\tmpeo8yo5_r\model.ckpt

# %%
input_sequence = saints_test # set desired note sequence
num_steps = 228 # change this for shorter or longer sequences
temperature = 1.0 # the higher the temperature the more random the sequence.

# %%
mm.plot_sequence(input_sequence)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0faf7aca-67be-4da9-9370-01278eae2852">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="6aa5f91e-da17-4ba7-9fe2-49929b8172fd"></div>
# </div>

# %%
#sequence = melody_rnn.generate(input_sequence, input_sequence)

# %%
last_end_time = (max(n.end_time for n in input_sequence.notes)
                  if input_sequence.notes else 0)
#qpm = input_sequence.tempos[0].qpm

# %%
qpm = input_sequence.tempos 
print(qpm)
# Out:
# [qpm: 120.0
# ]

# %%
# Set the start time to begin on the next step after the last note ends.
last_end_time = (max(n.end_time for n in input_sequence.notes)
                  if input_sequence.notes else 0)
qpm = input_sequence.tempos[0].qpm 
seconds_per_step = 60.0 / qpm / melody_rnn.steps_per_quarter
total_seconds = num_steps * seconds_per_step

generator_options = generator_pb2.GeneratorOptions()
generator_options.args['temperature'].float_value = temperature
generate_section = generator_options.generate_sections.add(
  start_time=last_end_time + seconds_per_step,
  end_time=total_seconds)

# Ask the model to continue the sequence.
sequence = melody_rnn.generate(input_sequence, generator_options)

mm.plot_sequence(sequence)
# Out:
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -98.143295
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5a2f9164-4165-472b-9026-7a9fc6c34244">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="2755c80a-3a39-4e8b-8eeb-32e05d6330d0"></div>
# </div>

# %%
mm.sequence_proto_to_midi_file(sequence, 'new_sequence.mid')

# %%
type(sequence)
# Out:
# music_pb2.NoteSequence

# %%
# DON"T RUN
filename = "zelda_tfrecord.tfrecord"
file = open(filename, "r")
for line in file:
   print line

# %%
import demjson

# %%
obj = sequence

# %%
#decode = demjson.decode(obj)

# %%
test = sequence.notes[1].pitch
test
# Out:
# 64

# %%
len(sequence.notes)
# Out:
# 37

# %%
pitch = []
velocity = []
for i in sequence.notes:
    pitch.append(i.pitch)
    velocity.append(i.velocity)

# %%
file = open('zelda_tfrecord.tfrecord', 'rb')
# Out:
# C:\Users\misir\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: ResourceWarning: unclosed file <_io.BufferedReader name='zelda_tfrecord.tfrecord'>

# %%
# Out:
# <_io.BufferedReader name='zelda_tfrecord.tfrecord'>

# %%
plt.scatter(velocity, pitch)
